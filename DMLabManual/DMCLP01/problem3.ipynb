# %% [markdown]
# ### Develop a jupyter notebook in Colab using all of the data processing criteria mentioned below.
# - a. Load the dataset
# - b. Find the data types of each column
# - c. Find if have any missing value
# - d. Print only the rows that contains missing value
# - e. Drop the missing value rows
# - f. Fill the missing value rows with mean and median
# - g. Drop Duplicates value
# - h. Encode label of all categorical columns

# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv("kidney_disease.csv")
df
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
# Find the data types of each column
df.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv                object
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
# Find if there are any missing values
df.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
# Print only the rows that contain missing values
df[df.isnull().any(axis=1)]
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN  normal  notpresent  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN  normal  notpresent  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal  normal  notpresent  notpresent
# 4      4  51.0  80.0  1.010  2.0  0.0  normal  normal  notpresent  notpresent
# 5      5  60.0  90.0  1.015  3.0  0.0     NaN     NaN  notpresent  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...     ...         ...         ...
# 350  350  65.0  70.0  1.025  0.0  0.0     NaN     NaN  notpresent  notpresent
# 363  363  67.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 365  365  24.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 378  378  71.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 381  381  71.0  70.0  1.025  0.0  0.0     NaN     NaN  notpresent  notpresent
#
# ...

# %%
# Drop the missing value rows
df = df.dropna()
df
# Out:
#       id   age    bp     sg   al   su       rbc        pc         pcc  \
# 3      3  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present
# 9      9  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 11    11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 14    14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present
# 20    20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
# ..   ...   ...   ...    ...  ...  ...       ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0    normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0    normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0    normal    normal  notpresent
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
# Drop duplicates
df = df.drop_duplicates()
df
# Out:
#       id   age    bp     sg   al   su       rbc        pc         pcc  \
# 3      3  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present
# 9      9  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 11    11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 14    14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present
# 20    20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
# ..   ...   ...   ...    ...  ...  ...       ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0    normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0    normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0    normal    normal  notpresent
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# ...
